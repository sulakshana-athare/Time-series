# %%
import pandas as pd

df=pd.read_csv('C:\\Users\\Sulakshana\\Desktop\\INSAID\\Machine-Learning-Foundation\\Project-ML\\Covid_data.csv')
df
# Out:
#       Unnamed: 0  confirmed  deaths   timestamp provincestate  longitude  \
# 0              0        1.0     0.0  1584920583           NaN   -61.6790
# 1              1      134.0     2.0  1584920583           NaN   -83.7534
# 2              2      789.0    14.0  1584920583           NaN   -78.1834
# 3              3      425.0     5.0  1584920583       Ontario   -85.3232
# 4              4      327.0    14.0  1584920583           NaN    30.8025
# ...          ...        ...     ...         ...           ...        ...
# 8432        8432        NaN     NaN  1579687200         Tibet        NaN
# 8433        8433        1.0     NaN  1579687200        Fujian        NaN
# 8434        8434        4.0     NaN  1579687200       Tianjin        NaN
# 8435        8435        1.0     NaN  1579687200        Taiwan        NaN
# 8436        8436        1.0     NaN  1579687200         Anhui        NaN
#
#       latitude  recovered   countryregion
# 0      12.1165        0.0         Grenada
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  confirmed  deaths   timestamp provincestate  longitude  \
# 0           0        1.0     0.0  1584920583           NaN   -61.6790
# 1           1      134.0     2.0  1584920583           NaN   -83.7534
# 2           2      789.0    14.0  1584920583           NaN   -78.1834
# 3           3      425.0     5.0  1584920583       Ontario   -85.3232
# 4           4      327.0    14.0  1584920583           NaN    30.8025
#
#    latitude  recovered countryregion
# 0   12.1165        0.0       Grenada
# 1    9.7489        2.0    Costa Rica
# 2   -1.8312        3.0       Ecuador
# 3   51.2538        6.0        Canada
# 4   26.8206       56.0         Egypt

# %%
df.tail(5)
# Out:
#       Unnamed: 0  confirmed  deaths   timestamp provincestate  longitude  \
# 8432        8432        NaN     NaN  1579687200         Tibet        NaN
# 8433        8433        1.0     NaN  1579687200        Fujian        NaN
# 8434        8434        4.0     NaN  1579687200       Tianjin        NaN
# 8435        8435        1.0     NaN  1579687200        Taiwan        NaN
# 8436        8436        1.0     NaN  1579687200         Anhui        NaN
#
#       latitude  recovered   countryregion
# 8432       NaN        NaN  Mainland China
# 8433       NaN        NaN  Mainland China
# 8434       NaN        NaN  Mainland China
# 8435       NaN        NaN          Taiwan
# 8436       NaN        NaN  Mainland China

# %%
df.describe()
# Out:
#         Unnamed: 0     confirmed       deaths     timestamp    longitude  \
# count  8437.000000   8418.000000  8050.000000  8.437000e+03  5681.000000
# mean   4218.000000    645.215015    23.715776  1.583115e+09     4.989828
# std    2435.696444   4947.302515   232.887300  1.420818e+06    84.687158
# min       0.000000      0.000000     0.000000  1.579687e+09  -157.858400
# 25%    2109.000000      2.000000     0.000000  1.582112e+09   -75.507100
# 50%    4218.000000     15.000000     0.000000  1.583605e+09    10.451500
# 75%    6327.000000    125.000000     1.000000  1.584219e+09    85.240100
# max    8436.000000  67800.000000  5476.000000  1.584921e+09   178.065000
#
#           latitude     recovered
# count  5681.000000   8087.000000
# mean     29.165968    249.113763
# std      21.888420   2783.047111
# min     -41.454500      0.000000
# 25%      21.000000      0.000000
# 50%      35.443700      0.000000
# 75%      42.756000     11.000000
# max      72.000000  59433.000000

# %%
df.shape
# Out:
# (8437, 9)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# confirmed          19
# deaths            387
# timestamp           0
# provincestate    3674
# longitude        2756
# latitude         2756
# recovered         350
# countryregion       0
# dtype: int64

# %%
df = df.drop(columns=["Unnamed: 0"], axis=1)
df["confirmed"].fillna(0,inplace= True)
df["deaths"].fillna(0,inplace= True)
df["recovered"].fillna(0,inplace= True)
df
# Out:
#       confirmed  deaths   timestamp provincestate  longitude  latitude  \
# 0           1.0     0.0  1584920583           NaN   -61.6790   12.1165
# 1         134.0     2.0  1584920583           NaN   -83.7534    9.7489
# 2         789.0    14.0  1584920583           NaN   -78.1834   -1.8312
# 3         425.0     5.0  1584920583       Ontario   -85.3232   51.2538
# 4         327.0    14.0  1584920583           NaN    30.8025   26.8206
# ...         ...     ...         ...           ...        ...       ...
# 8432        0.0     0.0  1579687200         Tibet        NaN       NaN
# 8433        1.0     0.0  1579687200        Fujian        NaN       NaN
# 8434        4.0     0.0  1579687200       Tianjin        NaN       NaN
# 8435        1.0     0.0  1579687200        Taiwan        NaN       NaN
# 8436        1.0     0.0  1579687200         Anhui        NaN       NaN
#
#       recovered   countryregion
# 0           0.0         Grenada
# 1           2.0      Costa Rica
# ...

# %%
df.describe()
# Out:
#           confirmed       deaths     timestamp    longitude     latitude  \
# count   8437.000000  8437.000000  8.437000e+03  5681.000000  5681.000000
# mean     643.762001    22.627948  1.583115e+09     4.989828    29.165968
# std     4941.822741   227.536861  1.420818e+06    84.687158    21.888420
# min        0.000000     0.000000  1.579687e+09  -157.858400   -41.454500
# 25%        2.000000     0.000000  1.582112e+09   -75.507100    21.000000
# 50%       15.000000     0.000000  1.583605e+09    10.451500    35.443700
# 75%      125.000000     1.000000  1.584219e+09    85.240100    42.756000
# max    67800.000000  5476.000000  1.584921e+09   178.065000    72.000000
#
#           recovered
# count   8437.000000
# mean     238.779542
# std     2725.155655
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        9.000000
# max    59433.000000

# %%
df_date = df.timestamp.apply(lambda x: pd.Timestamp(x, unit='s').strftime('%m-%d-%Y') )
df_date
# Out:
# 0       03-22-2020
# 1       03-22-2020
# 2       03-22-2020
# 3       03-22-2020
# 4       03-22-2020
#            ...
# 8432    01-22-2020
# 8433    01-22-2020
# 8434    01-22-2020
# 8435    01-22-2020
# 8436    01-22-2020
# Name: timestamp, Length: 8437, dtype: object

# %%
df.columns
# Out:
# Index(['confirmed', 'deaths', 'timestamp', 'provincestate', 'longitude',
#        'latitude', 'recovered', 'countryregion'],
#       dtype='object')

# %%
df1 = df.drop(columns=["timestamp","provincestate","longitude","latitude"], axis=1)
column_names = ["countryregion", "confirmed", "deaths", "recovered"]
df1 = df1.reindex(columns = column_names)
df1.rename(columns={"countryregion":"Country","confirmed":"Confirmed","deaths":"Deaths","recovered":"Recovered",},inplace=True)
df1
# Out:
#              Country  Confirmed  Deaths  Recovered
# 0            Grenada        1.0     0.0        0.0
# 1         Costa Rica      134.0     2.0        2.0
# 2            Ecuador      789.0    14.0        3.0
# 3             Canada      425.0     5.0        6.0
# 4              Egypt      327.0    14.0       56.0
# ...              ...        ...     ...        ...
# 8432  Mainland China        0.0     0.0        0.0
# 8433  Mainland China        1.0     0.0        0.0
# 8434  Mainland China        4.0     0.0        0.0
# 8435          Taiwan        1.0     0.0        0.0
# 8436  Mainland China        1.0     0.0        0.0
#
# [8437 rows x 4 columns]

# %%
df_final = pd.concat([df_date,df1],axis=1)
df_final
# Out:
#        timestamp         Country  Confirmed  Deaths  Recovered
# 0     03-22-2020         Grenada        1.0     0.0        0.0
# 1     03-22-2020      Costa Rica      134.0     2.0        2.0
# 2     03-22-2020         Ecuador      789.0    14.0        3.0
# 3     03-22-2020          Canada      425.0     5.0        6.0
# 4     03-22-2020           Egypt      327.0    14.0       56.0
# ...          ...             ...        ...     ...        ...
# 8432  01-22-2020  Mainland China        0.0     0.0        0.0
# 8433  01-22-2020  Mainland China        1.0     0.0        0.0
# 8434  01-22-2020  Mainland China        4.0     0.0        0.0
# 8435  01-22-2020          Taiwan        1.0     0.0        0.0
# 8436  01-22-2020  Mainland China        1.0     0.0        0.0
#
# [8437 rows x 5 columns]

# %%
df_final.rename(columns={"timestamp":"Date"},inplace=True)
df_final
# Out:
#             Date         Country  Confirmed  Deaths  Recovered
# 0     03-22-2020         Grenada        1.0     0.0        0.0
# 1     03-22-2020      Costa Rica      134.0     2.0        2.0
# 2     03-22-2020         Ecuador      789.0    14.0        3.0
# 3     03-22-2020          Canada      425.0     5.0        6.0
# 4     03-22-2020           Egypt      327.0    14.0       56.0
# ...          ...             ...        ...     ...        ...
# 8432  01-22-2020  Mainland China        0.0     0.0        0.0
# 8433  01-22-2020  Mainland China        1.0     0.0        0.0
# 8434  01-22-2020  Mainland China        4.0     0.0        0.0
# 8435  01-22-2020          Taiwan        1.0     0.0        0.0
# 8436  01-22-2020  Mainland China        1.0     0.0        0.0
#
# [8437 rows x 5 columns]

# %%
df_final.Country.value_counts()
# Out:
# US                1817
# Mainland China    1520
# China              429
# Australia          340
# Canada             262
#                   ...
# Grenada              1
# Ivory Coast          1
#  Azerbaijan          1
# Syria                1
# Timor-Leste          1
# Name: Country, Length: 215, dtype: int64

# %%
df2=df_final.groupby(['Date','Country']).count()
df2
# Out:
#                            Confirmed  Deaths  Recovered
# Date       Country
# 01-22-2020 Hong Kong               1       1          1
#            Japan                   1       1          1
#            Macau                   1       1          1
#            Mainland China         31      31         31
#            South Korea             1       1          1
# ...                              ...     ...        ...
# 03-22-2020 United Kingdom          3       3          3
#            Uruguay                 1       1          1
#            Venezuela               1       1          1
#            Vietnam                 1       1          1
#            Zambia                  1       1          1
#
# [2435 rows x 3 columns]

# %%
column_names = ["Country","Date","Confirmed","Deaths","Recovered"]
df_final1 = df_final.reindex(columns = column_names)
df_final1
# Out:
#              Country        Date  Confirmed  Deaths  Recovered
# 0            Grenada  03-22-2020        1.0     0.0        0.0
# 1         Costa Rica  03-22-2020      134.0     2.0        2.0
# 2            Ecuador  03-22-2020      789.0    14.0        3.0
# 3             Canada  03-22-2020      425.0     5.0        6.0
# 4              Egypt  03-22-2020      327.0    14.0       56.0
# ...              ...         ...        ...     ...        ...
# 8432  Mainland China  01-22-2020        0.0     0.0        0.0
# 8433  Mainland China  01-22-2020        1.0     0.0        0.0
# 8434  Mainland China  01-22-2020        4.0     0.0        0.0
# 8435          Taiwan  01-22-2020        1.0     0.0        0.0
# 8436  Mainland China  01-22-2020        1.0     0.0        0.0
#
# [8437 rows x 5 columns]

# %%
df3=df_final1.groupby(['Country','Date']).count()
df3
# Out:
#                                            Confirmed  Deaths  Recovered
# Country                        Date
#  Azerbaijan                    02-28-2020          1       1          1
# Afghanistan                    02-24-2020         13      13         13
#                                03-08-2020          3       3          3
#                                03-10-2020          2       2          2
#                                03-11-2020          4       4          4
# ...                                              ...     ...        ...
# Zambia                         03-22-2020          1       1          1
# Zimbabwe                       03-20-2020          1       1          1
#                                03-21-2020          2       2          2
# occupied Palestinian territory 03-10-2020          2       2          2
#                                03-11-2020          7       7          7
#
# [2435 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df_final1.groupby(['Country'])['Confirmed'].mean().plot(kind='bar', figsize=(55, 20), color='blue')
df_final1.groupby(['Country'])['Deaths'].mean().plot(kind='bar', figsize=(55, 20), color='red')
df_final1.groupby(['Country'])['Recovered'].mean().plot(kind='bar', figsize=(55, 20), color='green', fontsize=13)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)


plt.xlabel('Country')
plt.ylabel('Cases')
plt.title('Stacked Bar Chart showing the Corona cases in each Country')
plt.legend(labels=('Confirmed', 'Deaths', 'Recovered'))

# %%
df_final.Date.value_counts()
# Out:
# 03-11-2020    691
# 03-10-2020    396
# 03-08-2020    313
# 03-14-2020    305
# 03-16-2020    291
#              ...
# 02-10-2020     41
# 01-24-2020     41
# 02-14-2020     41
# 02-18-2020     40
# 01-22-2020     38
# Name: Date, Length: 61, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df_final1.groupby(['Date'])['Confirmed'].mean().plot(kind='bar', figsize=(55, 20), color='blue')
df_final1.groupby(['Date'])['Deaths'].mean().plot(kind='bar', figsize=(55, 20), color='red')
df_final1.groupby(['Date'])['Recovered'].mean().plot(kind='bar', figsize=(55, 20), color='green', fontsize=13)

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

plt.xlabel('Date')
plt.ylabel('Cases')
plt.title('Stacked Bar Chart showing the Corona cases at each Day',fontdict={'fontsize':50})
plt.legend(labels=('Confirmed', 'Deaths', 'Recovered'))

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(color_codes=True)

# %%
sns.pairplot(data=df1[['Confirmed','Deaths','Recovered']],height=2.5,diag_kind='kde')

# %%
corr_df=df_final.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_df,annot=True,cmap='RdBu')

# %% [markdown]
# This part is scary for Covid-19: High correlation between confirmed cases and deaths 0.95

# %%
df_final.Country.value_counts().plot.pie(figsize=(25,25))

# %%
space=np.ones(215)/215
df_final.Country.value_counts().plot.pie(explode=space,fontsize=14,autopct='%.2f%%',wedgeprops=dict(width=0.15),shadow=True,startangle=180,figsize=(30,30),colormap='inferno',legend=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd

# %%
df["longitude"].fillna(0,inplace= True)
df["latitude"].fillna(0,inplace= True)
df
# Out:
#       confirmed  deaths   timestamp provincestate  longitude  latitude  \
# 0           1.0     0.0  1584920583           NaN   -61.6790   12.1165
# 1         134.0     2.0  1584920583           NaN   -83.7534    9.7489
# 2         789.0    14.0  1584920583           NaN   -78.1834   -1.8312
# 3         425.0     5.0  1584920583       Ontario   -85.3232   51.2538
# 4         327.0    14.0  1584920583           NaN    30.8025   26.8206
# ...         ...     ...         ...           ...        ...       ...
# 8432        0.0     0.0  1579687200         Tibet     0.0000    0.0000
# 8433        1.0     0.0  1579687200        Fujian     0.0000    0.0000
# 8434        4.0     0.0  1579687200       Tianjin     0.0000    0.0000
# 8435        1.0     0.0  1579687200        Taiwan     0.0000    0.0000
# 8436        1.0     0.0  1579687200         Anhui     0.0000    0.0000
#
#       recovered   countryregion
# 0           0.0         Grenada
# 1           2.0      Costa Rica
# ...

# %%
nolong_df = df[df['longitude'] == 0.0000]
nolong_df
# Out:
#       confirmed  deaths   timestamp      provincestate  longitude  latitude  \
# 5415       95.0     2.0  1583020382          Hong Kong        0.0       0.0
# 5416      168.0     5.0  1583019782             Hainan        0.0       0.0
# 5419        8.0     0.0  1583018593   British Columbia        0.0       0.0
# 5420       10.0     0.0  1583018593        Toronto, ON        0.0       0.0
# 5421        2.0     0.0  1583017986  Western Australia        0.0       0.0
# ...         ...     ...         ...                ...        ...       ...
# 8432        0.0     0.0  1579687200              Tibet        0.0       0.0
# 8433        1.0     0.0  1579687200             Fujian        0.0       0.0
# 8434        4.0     0.0  1579687200            Tianjin        0.0       0.0
# 8435        1.0     0.0  1579687200             Taiwan        0.0       0.0
# 8436        1.0     0.0  1579687200              Anhui        0.0       0.0
#
#       recovered   countryregion
# ...

# %%
long_df = df[df['longitude'] != 0.0000]
long_df
# Out:
#       confirmed  deaths   timestamp    provincestate  longitude  latitude  \
# 0           1.0     0.0  1584920583              NaN   -61.6790   12.1165
# 1         134.0     2.0  1584920583              NaN   -83.7534    9.7489
# 2         789.0    14.0  1584920583              NaN   -78.1834   -1.8312
# 3         425.0     5.0  1584920583          Ontario   -85.3232   51.2538
# 4         327.0    14.0  1584920583              NaN    30.8025   26.8206
# ...         ...     ...         ...              ...        ...       ...
# 7723        1.0     0.0  1580586783       Orange, CA  -117.8531   33.7879
# 7724        1.0     0.0  1580586783  Los Angeles, CA  -118.2437   34.0522
# 7725        1.0     0.0  1580586783       Orange, CA  -117.8531   33.7879
# 7726        1.0     0.0  1580586783  Los Angeles, CA  -118.2437   34.0522
# 7747        1.0     0.0  1580586783       Orange, CA  -117.8531   33.7879
#
#       recovered countryregion
# 0           0.0       Grenada
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
w_map = gpd.read_file('C:\\Users\\Sulakshana\\Desktop\\INSAID\\Machine-Learning-Foundation\\Project-ML\\TM_WORLD_BORDERS-0.3.shp')

# %%
fig, ax = plt.subplots(figsize = (15,15))
w_map.plot(ax = ax)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
crs = {'init': 'epsg:4326'}
df.head(5)
# Out:
#    confirmed  deaths   timestamp provincestate  longitude  latitude  \
# 0        1.0     0.0  1584920583           NaN   -61.6790   12.1165
# 1      134.0     2.0  1584920583           NaN   -83.7534    9.7489
# 2      789.0    14.0  1584920583           NaN   -78.1834   -1.8312
# 3      425.0     5.0  1584920583       Ontario   -85.3232   51.2538
# 4      327.0    14.0  1584920583           NaN    30.8025   26.8206
#
#    recovered countryregion
# 0        0.0       Grenada
# 1        2.0    Costa Rica
# 2        3.0       Ecuador
# 3        6.0        Canada
# 4       56.0         Egypt

# %%
geometry = [Point(xy) for xy in zip(long_df["longitude"],df["latitude"])]
geometry[:3]

# %%
geo_df = gpd.GeoDataFrame(long_df,crs=crs,geometry=geometry)
geo_df.head(5)
# Out:
#    confirmed  deaths   timestamp provincestate  longitude  latitude  \
# 0        1.0     0.0  1584920583           NaN   -61.6790   12.1165
# 1      134.0     2.0  1584920583           NaN   -83.7534    9.7489
# 2      789.0    14.0  1584920583           NaN   -78.1834   -1.8312
# 3      425.0     5.0  1584920583       Ontario   -85.3232   51.2538
# 4      327.0    14.0  1584920583           NaN    30.8025   26.8206
#
#    recovered countryregion                    geometry
# 0        0.0       Grenada  POINT (-61.67900 12.11650)
# 1        2.0    Costa Rica   POINT (-83.75340 9.74890)
# 2        3.0       Ecuador  POINT (-78.18340 -1.83120)
# 3        6.0        Canada  POINT (-85.32320 51.25380)
# 4       56.0         Egypt   POINT (30.80250 26.82060)

# %%
geo_df.tail(5)
# Out:
#       confirmed  deaths   timestamp    provincestate  longitude  latitude  \
# 7723        1.0     0.0  1580586783       Orange, CA  -117.8531   33.7879
# 7724        1.0     0.0  1580586783  Los Angeles, CA  -118.2437   34.0522
# 7725        1.0     0.0  1580586783       Orange, CA  -117.8531   33.7879
# 7726        1.0     0.0  1580586783  Los Angeles, CA  -118.2437   34.0522
# 7747        1.0     0.0  1580586783       Orange, CA  -117.8531   33.7879
#
#       recovered countryregion                     geometry
# 7723        0.0            US  POINT (-117.85310 38.47470)
# 7724        0.0            US  POINT (-118.24370 38.47470)
# 7725        0.0            US  POINT (-117.85310 38.47470)
# 7726        0.0            US  POINT (-118.24370 38.47470)
# 7747        0.0            US  POINT (-117.85310 38.47470)

# %%
conda install -c conda-forge descartes
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - descartes
#
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/win-64::python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.3-py37_0 --> conda-forge::conda-4.8.3-py37hc8dfbb8_1
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
 conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.1|             py_0          11 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     future-0.18.2              |           py37_0         656 KB
#     matplotlib-base-3.1.3      |   py37h64f37c6_0         4.9 MB
#     ------------------------------------------------------------
#                                            Total:         8.4 MB
#
# The following packages will be REMOVED:
#
#   python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   backports.functoo~                               1.5-py_2 --> 1.6.1-py_0
# ...

# %%
conda install geopandas
# Out:
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     click-plugins-1.1.1        |             py_0          11 KB
#     cligj-0.5.0                |           py37_0          12 KB
#     expat-2.2.5                |       he025d50_0          83 KB
#     fiona-1.8.4                |   py37h22081e2_0         605 KB
#     freexl-1.0.5               |       hfa6e2cd_0          50 KB
#     gdal-2.3.3                 |   py37hdf43c64_0         984 KB
# ...

# %%
fig,ax = plt.subplots(figsize=(15,15))
w_map.plot(ax = ax, alpha = 0.4, color = 'grey')
geo_df.plot(ax=ax, markersize=geo_df["confirmed"]/100, color="blue", marker = "o", label="Confirmed")

# %%
fig,ax = plt.subplots(figsize=(15,15))
w_map.plot(ax = ax, alpha = 0.4, color = 'grey')
geo_df.plot(ax=ax, markersize=geo_df["deaths"]/100, color="red", marker = "o", label="Confirmed")

# %%
fig,ax = plt.subplots(figsize=(15,15))
w_map.plot(ax = ax, alpha = 0.4, color = 'grey')
geo_df.plot(ax=ax, markersize=geo_df["recovered"]/100, color="green", marker = "o", label="Confirmed")

# %%
# Divide and Conquer
df_US = df_final1[df_final1['Country']=="US"]
df_US
# Out:
#      Country        Date  Confirmed  Deaths  Recovered
# 23        US  03-22-2020     1996.0    95.0        0.0
# 52        US  03-22-2020      355.0     3.0        0.0
# 54        US  03-22-2020      646.0     5.0        0.0
# 55        US  03-22-2020      627.0     6.0        0.0
# 56        US  03-22-2020      509.0     3.0        0.0
# ...      ...         ...        ...     ...        ...
# 8303      US  01-25-2020        1.0     0.0        0.0
# 8315      US  01-24-2020        1.0     0.0        0.0
# 8331      US  01-24-2020        1.0     0.0        0.0
# 8396      US  01-23-2020        1.0     0.0        0.0
# 8431      US  01-22-2020        1.0     0.0        0.0
#
# [1817 rows x 5 columns]

# %%
df_US.groupby(['Date'])['Confirmed'].mean().plot(kind='bar', figsize=(50, 30), color='blue')
df_US.groupby(['Date'])['Deaths'].mean().plot(kind='bar', figsize=(50, 30), color='red')
df_US.groupby(['Date'])['Recovered'].mean().plot(kind='bar', figsize=(50, 30), color='green')

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

plt.xlabel('Date',fontdict={'fontsize':50})
plt.ylabel('Cases', fontdict={'fontsize':50})
plt.title('Stacked Bar Chart showing the Corona cases on each Day in US', fontdict={'fontsize':50})
plt.legend(labels=('Confirmed', 'Deaths', 'Recovered'))

# %%
df_US.groupby(['Date'])['Confirmed'].mean().plot(kind='line', figsize=(50, 30), color='blue',fontsize=20, linestyle='-.')
df_US.groupby(['Date'])['Deaths'].mean().plot(kind='line', figsize=(50, 30), color='red',fontsize=20, linestyle='-.')
df_US.groupby(['Date'])['Recovered'].mean().plot(kind='line', figsize=(50, 30), color='green', fontsize=20, linestyle='-.')

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

plt.xlabel('Date',fontdict={'fontsize':50})
plt.ylabel('Cases', fontdict={'fontsize':50})
plt.title('The plot showing the Corona cases on each Day in US', fontdict={'fontsize':50})
plt.legend(labels=('Confirmed', 'Deaths', 'Recovered'))

# %%
# Problem: To predict daily change(rate) of confirmed cases

# %%
df_US1 = df_final[df_final.Country == "US"]
df_US1 = df_US1.sort_values(by=["Date"])
df_US1 = df_US1[1:]
df_US1['DoD_conf'] = df_US1.Confirmed.pct_change()
df_US1['TargetConf'] = df_US1.DoD_conf.apply(lambda x: '1' if x>0 else '0')
df_US1
# Out:
#             Date Country  Confirmed  Deaths  Recovered  DoD_conf TargetConf
# 8396  01-23-2020      US        1.0     0.0        0.0       NaN          0
# 8315  01-24-2020      US        1.0     0.0        0.0  0.000000          0
# 8331  01-24-2020      US        1.0     0.0        0.0  0.000000          0
# 8292  01-25-2020      US        1.0     0.0        0.0  0.000000          0
# 8303  01-25-2020      US        1.0     0.0        0.0  0.000000          0
# ...          ...     ...        ...     ...        ...       ...        ...
# 88    03-22-2020      US       24.0     0.0        0.0 -0.111111          0
# 87    03-22-2020      US       83.0     0.0        0.0  2.458333          1
# 86    03-22-2020      US      152.0     2.0        0.0  0.831325          1
# 99    03-22-2020      US      207.0     1.0        0.0  0.361842          1
# 23    03-22-2020      US     1996.0    95.0        0.0  8.642512          1
#
# [1816 rows x 7 columns]

# %%
df_US = df_US1.drop(columns= ["Date","Country","Deaths","Recovered"],axis = 1)
df_US
# Out:
#       Confirmed  DoD_conf TargetConf
# 8396        1.0       NaN          0
# 8315        1.0  0.000000          0
# 8331        1.0  0.000000          0
# 8292        1.0  0.000000          0
# 8303        1.0  0.000000          0
# ...         ...       ...        ...
# 88         24.0 -0.111111          0
# 87         83.0  2.458333          1
# 86        152.0  0.831325          1
# 99        207.0  0.361842          1
# 23       1996.0  8.642512          1
#
# [1816 rows x 3 columns]

# %%
df_US.dropna()
# Out:
#       Confirmed  DoD_conf TargetConf
# 8315        1.0  0.000000          0
# 8331        1.0  0.000000          0
# 8292        1.0  0.000000          0
# 8303        1.0  0.000000          0
# 8267        1.0  0.000000          0
# ...         ...       ...        ...
# 88         24.0 -0.111111          0
# 87         83.0  2.458333          1
# 86        152.0  0.831325          1
# 99        207.0  0.361842          1
# 23       1996.0  8.642512          1
#
# [1737 rows x 3 columns]

# %%
df_n = df_US[~df_US.isin([np.nan,np.inf,-np.inf]).any(1)]
df_n
# Out:
#       Confirmed  DoD_conf TargetConf
# 8315        1.0  0.000000          0
# 8331        1.0  0.000000          0
# 8292        1.0  0.000000          0
# 8303        1.0  0.000000          0
# 8267        1.0  0.000000          0
# ...         ...       ...        ...
# 88         24.0 -0.111111          0
# 87         83.0  2.458333          1
# 86        152.0  0.831325          1
# 99        207.0  0.361842          1
# 23       1996.0  8.642512          1
#
# [1715 rows x 3 columns]

# %%
df_n.DoD_conf.unique()
# Out:
# array([ 0.00000000e+00,  1.00000000e+00, -5.00000000e-01,  1.00000000e+01,
#        -5.45454545e-01, -6.00000000e-01, -8.18181818e-01,  1.50000000e+00,
#        -1.00000000e+00, -9.72222222e-01,  4.10000000e+01, -9.52380952e-01,
#         4.30000000e+01, -9.77272727e-01, -9.31818182e-01, -6.66666667e-01,
#         5.00000000e+00,  3.50000000e+00, -5.55555556e-01, -7.50000000e-01,
#         1.30000000e+01, -9.28571429e-01,  3.00000000e+00,  8.00000000e+00,
#        -8.88888889e-01,  4.40000000e+01, -9.77777778e-01,  2.15000000e+01,
#        -9.55555556e-01,  2.50000000e+00, -9.04761905e-01,  4.50000000e+00,
#         3.00000000e+01, -6.77419355e-01, -8.00000000e-01, -1.25000000e-01,
#        -5.71428571e-01,  2.00000000e+00,  1.75000000e+00,  6.36363636e-01,
#        -9.44444444e-01,  9.00000000e+00, -9.50000000e-01,  5.00000000e+01,
#        -9.80392157e-01,  4.00000000e+00,  1.70000000e+01, -3.33333333e-01,
# ...

# %%
df_cat = df_n[["TargetConf"]]
df_cont = df_n[["Confirmed","DoD_conf"]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(df_cont))
StandardScaler()
(scaler.mean_)

print(scaler.transform(df_cont))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [[-0.13216551 -0.12565382]
#  [-0.13216551 -0.12565382]
#  [-0.13216551 -0.12565382]
#  ...
#  [ 0.138691   -0.08923442]
#  [ 0.23734734 -0.10980194]
#  [ 3.44636912  0.25296458]]

# %%
df_co = pd.concat([df_cont, df_cat], axis = 1)

# %%
X = df_co.loc[:,df_co.columns != 'TargetConf']
X
# Out:
#       Confirmed  DoD_conf
# 8315        1.0  0.000000
# 8331        1.0  0.000000
# 8292        1.0  0.000000
# 8303        1.0  0.000000
# 8267        1.0  0.000000
# ...         ...       ...
# 88         24.0 -0.111111
# 87         83.0  2.458333
# 86        152.0  0.831325
# 99        207.0  0.361842
# 23       1996.0  8.642512
#
# [1715 rows x 2 columns]

# %%
y = df_co.loc[:,df_co.columns == 'TargetConf']
y
# Out:
#      TargetConf
# 8315          0
# 8331          0
# 8292          0
# 8303          0
# 8267          0
# ...         ...
# 88            0
# 87            1
# 86            1
# 99            1
# 23            1
#
# [1715 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20) 
X_train, X_test, y_train, y_test
# Out:
# (      Confirmed  DoD_conf
#  5545        1.0  0.000000
#  4165       14.0  0.555556
#  3818        1.0 -0.833333
#  470       122.0 -0.290698
#  3839        2.0 -0.333333
#  ...         ...       ...
#  3588        2.0  0.000000
#  6745        2.0  0.000000
#  1809        5.0  4.000000
#  4174        1.0  0.000000
#  4035        2.0  0.000000
#
#  [1372 rows x 2 columns],       Confirmed  DoD_conf
#  93         99.0 -0.282609
#  2101      164.0  0.188406
#  4245        2.0 -0.333333
#  7604        2.0  0.000000
#  4678        1.0 -0.980392
#  ...         ...       ...
#  749        88.0  0.086420
#  4415        1.0 -0.500000
#  2681       25.0 -0.931694
#  3666        0.0 -1.000000
#  3970        1.0  0.000000
#
#  [343 rows x 2 columns],      TargetConf
#  5545          0
#  4165          1
#  3818          0
#  470           0
#  3839          0
#  ...         ...
#  3588          0
#  6745          0
#  1809          1
#  4174          0
#  4035          0
#
# ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1372, 2)
# (1372, 1)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (343, 2)
# (343, 1)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_train = logreg.predict(X_train)

# %%
y_pred_test = logreg.predict(X_test)

# %%
# Model Evaluation by accuracy score
from sklearn.metrics import accuracy_score
print('Accuracy score for test data is:', accuracy_score(y_test,y_pred_test))
# Out:
# Accuracy score for test data is: 0.9825072886297376

# %%
# Model Evaluation by confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(y_test, y_pred_test))
confusion_matrix.index = ['Actual decrease','Actual increase']
confusion_matrix.columns = ['Predicted decrease','Predicted increase']
print(confusion_matrix)
# Out:
#                  Predicted decrease  Predicted increase
# Actual decrease                 257                   0
# Actual increase                   6                  80

# %%
print(y_pred_train.shape)
print(y_pred_test.shape)
# Out:
# (1372,)
# (343,)

# %%
predicted = np.array(y_test).tolist()

# %%
measured = np.array(y_pred_test).tolist()

# %%
predicted_df = pd.DataFrame(predicted)

# %%
measured_df = pd.DataFrame(measured)

# %%
# From heat map it is observed that between Confirmed and Fatal Cases there high correlation (0.95)
# Let's fit the data with linear regression only between confirmed and death cases.

data = df_US1.drop(columns=["Date","Country","Recovered","DoD_conf","TargetConf"],axis=1)
data
# Out:
#       Confirmed  Deaths
# 8396        1.0     0.0
# 8315        1.0     0.0
# 8331        1.0     0.0
# 8292        1.0     0.0
# 8303        1.0     0.0
# ...         ...     ...
# 88         24.0     0.0
# 87         83.0     0.0
# 86        152.0     2.0
# 99        207.0     1.0
# 23       1996.0    95.0
#
# [1816 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(data)
data1 = scaler.transform(data)

# %%
data = pd.DataFrame(data1)
data.head(5)
# Out:
#           0         1
# 0 -0.128577 -0.166196
# 1 -0.128577 -0.166196
# 2 -0.128577 -0.166196
# 3 -0.128577 -0.166196
# 4 -0.128577 -0.166196

# %%
data.columns = ['Confirmed','Deaths']
data.head()
# Out:
#    Confirmed    Deaths
# 0  -0.128577 -0.166196
# 1  -0.128577 -0.166196
# 2  -0.128577 -0.166196
# 3  -0.128577 -0.166196
# 4  -0.128577 -0.166196

# %%
feature_cols = ['Confirmed']                # create a Python list of feature names
X = data[feature_cols]
X
# Out:
#       Confirmed
# 0     -0.128577
# 1     -0.128577
# 2     -0.128577
# 3     -0.128577
# 4     -0.128577
# ...         ...
# 1811  -0.086143
# 1812   0.022709
# 1813   0.150011
# 1814   0.251484
# 1815   3.552108
#
# [1816 rows x 1 columns]

# %%
print(type(X))
print(X.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1816, 1)

# %%
y = data.Deaths
y.head()
# Out:
# 0   -0.166196
# 1   -0.166196
# 2   -0.166196
# 3   -0.166196
# 4   -0.166196
# Name: Deaths, dtype: float64

# %%
print(y.shape)
# Out:
# (1816,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1452, 1)
# (1452,)
# (364, 1)
# (364,)

# %%
from sklearn.linear_model import LinearRegression
import sklearn.metrics as metrics
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Intercept:',linreg.intercept_)          # print the intercept 
print('Coefficients:',linreg.coef_)
# Out:
# Intercept: -0.010259857018901019
# Coefficients: [0.64108052]

# %%
feature_cols.insert(0,'Intercept')
coef = linreg.coef_.tolist()            
coef.insert(0, linreg.intercept_)

# %%
eq1 = zip(feature_cols, coef)

for c1,c2 in eq1:
    print(c1,c2)
# Out:
# Intercept -0.010259857018901019
# Confirmed 0.6410805235848247

# %% [markdown]
# y = mx + C
# Deaths = 0.6410805235848247 * Confirmed + (-0.010259857018901019)
# A unit increase in confirmed patients increases fatal cases by 0.66 unit

# %%
y_pred_train = linreg.predict(X_train)

# %%
y_pred_test = linreg.predict(X_test)

# %%
MAE_train = metrics.mean_absolute_error(y_train, y_pred_train)
MAE_test = metrics.mean_absolute_error(y_test, y_pred_test)

# %%
print('MAE for training set is {}'.format(MAE_train))
print('MAE for test set is {}'.format(MAE_test))
# Out:
# MAE for training set is 0.169694350335211
# MAE for test set is 0.20078646576897569

# %%
MSE_train = metrics.mean_squared_error(y_train, y_pred_train)
MSE_test = metrics.mean_squared_error(y_test, y_pred_test)

# %%
print('MSE for training set is {}'.format(MSE_train))
print('MSE for test set is {}'.format(MSE_test))
# Out:
# MSE for training set is 0.42999639084010277
# MSE for test set is 0.9352217530318564

# %%
RMSE_train = np.sqrt( metrics.mean_squared_error(y_train, y_pred_train))
RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test))

# %%
print('RMSE for training set is {}'.format(RMSE_train))
print('RMSE for test set is {}'.format(RMSE_test))
# Out:
# RMSE for training set is 0.6557411004658034
# RMSE for test set is 0.9670686392556923

# %%
# Model Evaluation using R squared.
yhat = linreg.predict(X_train)
SS_Residual = sum((y_train-yhat)**2)
SS_Total = sum((y_train-np.mean(y_train))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(r_squared, adjusted_r_squared)
# Out:
# 0.37736361066403523 0.37693420625759666

# %% [markdown]
# As Rsquared is very less I am not going to report this in ppt.
